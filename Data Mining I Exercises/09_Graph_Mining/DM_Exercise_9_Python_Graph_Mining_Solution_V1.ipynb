# %% [markdown]
# Run the cell below if you are using Google Colab to mount your Google Drive in your Colab instance. Adjust the path to the files in your Google Drive as needed if it differs.
#
# If you do not use Google Colab, running the cell will simply do nothing, so do not worry about it.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive/')
    # %cd 'drive/My Drive/Colab Notebooks/09_Graph_Mining'
except ImportError as e:
    pass

# %% [markdown]
# ## Exercise 9: Graph Mining
#
# ### 9.1. Node2Vec for Node Classification
#
# #### 9.1.1 Load the CiteSeer dataset using the stellargraph dataset class

# %%
from stellargraph import datasets

dataset = datasets.CiteSeer()
G, node_subjects = dataset.load()

print(G.info())
print("\n\nnode subjects:")
print(node_subjects)

node_subjects.value_counts().to_frame()
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 3312, Edges: 4715
#
#  Node types:
#   paper: [3312]
#     Features: float32 vector, length 3703
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [4715]
#         Weights: all 1 (default)
#         Features: none
#
#
# node subjects:
# 100157                  Agents
# 100598                      IR
# 105684                  Agents
# 11099                       DB
# 114091                      AI
#                          ...
# zhang99query                DB
# zhang99situated             ML
# zhang99towards              IR
# zhou00implementation        DB
# 455346                      ML
# Name: subject, Length: 3312, dtype: object
#         subject
# DB          701
# IR          668
# Agents      596
# ML          590
# HCI         508
# AI          249

# %% [markdown]
# #### 9.1.2 Generate the Random Walks and train a Node2Vec (Word2Vec) model using the gensim library

# %%
from stellargraph.data import BiasedRandomWalk

rw = BiasedRandomWalk(G)

walks = rw.run(
    nodes=list(G.nodes()),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
)
print("Number of random walks: {}".format(len(walks)))
# Out:
# Number of random walks: 33120

# %%
from gensim.models import Word2Vec

str_walks = [[str(n) for n in walk] for walk in walks]

model = Word2Vec(str_walks, vector_size=128, window=5, min_count=0, sg=1, workers=2, epochs=20)

# %% [markdown]
# #### 9.1.3 Visualize the learned embeddings using t-SNE visualization.

# %%
from sklearn.manifold import TSNE

# Retrieve node embeddings and corresponding subjects
node_ids = model.wv.index_to_key  # list of node IDs
node_embeddings = (model.wv.vectors)  # numpy.ndarray of size number of nodes times embeddings dimensionality
node_targets = node_subjects[[node_id for node_id in node_ids]]

# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2)
node_embeddings_2d = tsne.fit_transform(node_embeddings)
# Out:
# C:\tools\Anaconda3\envs\dm1\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\tools\Anaconda3\envs\dm1\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))

for target_value in np.unique(node_targets):
    rows_of_target_value = np.where(node_targets==target_value)
    ax.scatter(
        node_embeddings_2d[rows_of_target_value, 0],
        node_embeddings_2d[rows_of_target_value, 1],
        alpha=0.4,
        label=target_value
    )

ax.legend(bbox_to_anchor=(1,1));
ax.set(
    aspect="equal",
    xlabel="$X_1$",
    ylabel="$X_2$",
    title=f"TSNE visualization of Node2Vec embeddings for CiteSeer dataset",
);

# %% [markdown]
# #### 9.1.4 Perform a train/test split and learn a classifier for the nodes using their Node2Vec embeddings as feature input

# %%
from sklearn.model_selection import train_test_split

node_ids = node_subjects.index
targets = node_subjects.values

node_ids_train, node_ids_test, target_train, target_test = train_test_split(
    node_ids, targets, test_size=0.2, stratify=targets, random_state=42
)

X_train = [model.wv[x] for x in node_ids_train]
X_test = [model.wv[x] for x in node_ids_test]

# %%
from sklearn.linear_model import LogisticRegressionCV

clf = LogisticRegressionCV(
    Cs=10, cv=10, scoring="accuracy", verbose=False, multi_class="ovr", max_iter=300
)
clf.fit(X_train, target_train)
# Out:
# LogisticRegressionCV(cv=10, max_iter=300, multi_class='ovr', scoring='accuracy',
#                      verbose=False)

# %% [markdown]
# #### 9.1.5 Evaluate the classifier on the split off test set using the Accuracy metric.

# %%
from sklearn.metrics import accuracy_score

y_pred = clf.predict(X_test)
accuracy_score(target_test, y_pred)
# Out:
# 0.5535444947209653

# %% [markdown]
# ### 9.2. Graph Neural Networks for Node Classification
#
# #### 9.2.1 Further split the previous train set in train and validation and create a GCN model using Keras

# %%
node_ids_train, node_ids_val, target_train, target_val = train_test_split(
    node_ids_train, target_train, test_size=0.25, stratify=target_train, random_state=42
)
print(f"train: {len(target_train)} validation: {len(target_val)} test: {len(target_test)}")
# Out:
# train: 1986 validation: 663 test: 663

# %%
from sklearn.preprocessing import LabelBinarizer

target_encoding = LabelBinarizer()

enc_target_train = target_encoding.fit_transform(target_train)
enc_target_val = target_encoding.transform(target_val)
enc_target_test = target_encoding.transform(target_test)

# %%
from stellargraph.mapper import FullBatchNodeGenerator


generator = FullBatchNodeGenerator(G, method="gcn")
train_gen = generator.flow(node_ids_train, enc_target_train)
val_gen = generator.flow(node_ids_val, enc_target_val)
# Out:
# Using GCN (local pooling) filters...

# %%
from stellargraph.layer import GCN
from tensorflow.keras import layers, optimizers, losses, metrics, Model

gcn = GCN(
    layer_sizes=[16, 16], activations=["relu", "relu"], generator=generator, dropout=0.5
)
x_inp, x_out = gcn.in_out_tensors()

predictions = layers.Dense(units=enc_target_train.shape[1], activation="softmax")(x_out)

model = Model(inputs=x_inp, outputs=predictions)
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.01),
    loss=losses.categorical_crossentropy,
    metrics=["acc"],
)

# %% [markdown]
# #### 9.2.2 Train the model and evaluate on the test set. Can the GCN improve over the Node2Vec approach?

# %%
from tensorflow.keras.callbacks import EarlyStopping

es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)

history = model.fit(
    train_gen,
    epochs=200,
    validation_data=val_gen,
    verbose=2,
    shuffle=False,  # this should be False, since shuffling data means shuffling the whole graph
    callbacks=[es_callback],
)
# Out:
# Epoch 1/200
# 1/1 - 1s - loss: 1.7926 - acc: 0.1425 - val_loss: 1.7417 - val_acc: 0.3756 - 1s/epoch - 1s/step
# Epoch 2/200
# 1/1 - 0s - loss: 1.7326 - acc: 0.3313 - val_loss: 1.6495 - val_acc: 0.4178 - 271ms/epoch - 271ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 1.6341 - acc: 0.4074 - val_loss: 1.5476 - val_acc: 0.4676 - 277ms/epoch - 277ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 1.5293 - acc: 0.4366 - val_loss: 1.4506 - val_acc: 0.5566 - 283ms/epoch - 283ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 1.4296 - acc: 0.5070 - val_loss: 1.3547 - val_acc: 0.6305 - 286ms/epoch - 286ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 1.3265 - acc: 0.5871 - val_loss: 1.2676 - val_acc: 0.6667 - 270ms/epoch - 270ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 1.2347 - acc: 0.6410 - val_loss: 1.1893 - val_acc: 0.6938 - 275ms/epoch - 275ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 1.1477 - acc: 0.6591 - val_loss: 1.1166 - val_acc: 0.7210 - 276ms/epoch - 276ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 1.0656 - acc: 0.6903 - val_loss: 1.0504 - val_acc: 0.7315 - 271ms/epoch - 271ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.9857 - acc: 0.7195 - val_loss: 0.9944 - val_acc: 0.7330 - 270ms/epoch - 270ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.9348 - acc: 0.7195 - val_loss: 0.9499 - val_acc: 0.7376 - 269ms/epoch - 269ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.8649 - acc: 0.7417 - val_loss: 0.9165 - val_acc: 0.7406 - 272ms/epoch - 272ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.8220 - acc: 0.7603 - val_loss: 0.8928 - val_acc: 0.7451 - 268ms/epoch - 268ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.7736 - acc: 0.7669 - val_loss: 0.8805 - val_acc: 0.7451 - 265ms/epoch - 265ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.7340 - acc: 0.7674 - val_loss: 0.8767 - val_acc: 0.7436 - 262ms/epoch - 262ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.6936 - acc: 0.7709 - val_loss: 0.8802 - val_acc: 0.7391 - 270ms/epoch - 270ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.6742 - acc: 0.7734 - val_loss: 0.8907 - val_acc: 0.7376 - 281ms/epoch - 281ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.6666 - acc: 0.7790 - val_loss: 0.9062 - val_acc: 0.7376 - 274ms/epoch - 274ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.6575 - acc: 0.7820 - val_loss: 0.9228 - val_acc: 0.7391 - 271ms/epoch - 271ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.6074 - acc: 0.7936 - val_loss: 0.9380 - val_acc: 0.7406 - 268ms/epoch - 268ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.5872 - acc: 0.8051 - val_loss: 0.9523 - val_acc: 0.7436 - 276ms/epoch - 276ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.5682 - acc: 0.8137 - val_loss: 0.9663 - val_acc: 0.7421 - 283ms/epoch - 283ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.5452 - acc: 0.8258 - val_loss: 0.9761 - val_acc: 0.7360 - 275ms/epoch - 275ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.5433 - acc: 0.8268 - val_loss: 0.9847 - val_acc: 0.7406 - 270ms/epoch - 270ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.5233 - acc: 0.8348 - val_loss: 0.9917 - val_acc: 0.7406 - 270ms/epoch - 270ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.5348 - acc: 0.8288 - val_loss: 0.9973 - val_acc: 0.7406 - 265ms/epoch - 265ms/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.5174 - acc: 0.8359 - val_loss: 1.0015 - val_acc: 0.7451 - 268ms/epoch - 268ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.4832 - acc: 0.8429 - val_loss: 1.0068 - val_acc: 0.7451 - 282ms/epoch - 282ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.4867 - acc: 0.8429 - val_loss: 1.0121 - val_acc: 0.7436 - 311ms/epoch - 311ms/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.4725 - acc: 0.8429 - val_loss: 1.0187 - val_acc: 0.7406 - 282ms/epoch - 282ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.4622 - acc: 0.8505 - val_loss: 1.0261 - val_acc: 0.7391 - 289ms/epoch - 289ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.4563 - acc: 0.8479 - val_loss: 1.0341 - val_acc: 0.7376 - 293ms/epoch - 293ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.4604 - acc: 0.8540 - val_loss: 1.0401 - val_acc: 0.7376 - 295ms/epoch - 295ms/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.4391 - acc: 0.8540 - val_loss: 1.0452 - val_acc: 0.7376 - 268ms/epoch - 268ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.4312 - acc: 0.8535 - val_loss: 1.0510 - val_acc: 0.7360 - 271ms/epoch - 271ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.4256 - acc: 0.8625 - val_loss: 1.0605 - val_acc: 0.7391 - 269ms/epoch - 269ms/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.4077 - acc: 0.8676 - val_loss: 1.0748 - val_acc: 0.7376 - 269ms/epoch - 269ms/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.4138 - acc: 0.8661 - val_loss: 1.0905 - val_acc: 0.7391 - 270ms/epoch - 270ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.3983 - acc: 0.8656 - val_loss: 1.1082 - val_acc: 0.7360 - 279ms/epoch - 279ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.3912 - acc: 0.8661 - val_loss: 1.1272 - val_acc: 0.7360 - 280ms/epoch - 280ms/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.3792 - acc: 0.8625 - val_loss: 1.1474 - val_acc: 0.7360 - 279ms/epoch - 279ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.3929 - acc: 0.8625 - val_loss: 1.1659 - val_acc: 0.7376 - 268ms/epoch - 268ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.3872 - acc: 0.8651 - val_loss: 1.1830 - val_acc: 0.7330 - 264ms/epoch - 264ms/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.3983 - acc: 0.8630 - val_loss: 1.1978 - val_acc: 0.7315 - 262ms/epoch - 262ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.3756 - acc: 0.8666 - val_loss: 1.2067 - val_acc: 0.7345 - 262ms/epoch - 262ms/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.3717 - acc: 0.8686 - val_loss: 1.2181 - val_acc: 0.7315 - 269ms/epoch - 269ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.3383 - acc: 0.8756 - val_loss: 1.2304 - val_acc: 0.7300 - 269ms/epoch - 269ms/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.3633 - acc: 0.8741 - val_loss: 1.2411 - val_acc: 0.7285 - 266ms/epoch - 266ms/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.3657 - acc: 0.8696 - val_loss: 1.2543 - val_acc: 0.7255 - 267ms/epoch - 267ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.3394 - acc: 0.8807 - val_loss: 1.2661 - val_acc: 0.7285 - 284ms/epoch - 284ms/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.3454 - acc: 0.8792 - val_loss: 1.2764 - val_acc: 0.7255 - 264ms/epoch - 264ms/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.3359 - acc: 0.8792 - val_loss: 1.2895 - val_acc: 0.7255 - 259ms/epoch - 259ms/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.3430 - acc: 0.8751 - val_loss: 1.2983 - val_acc: 0.7210 - 261ms/epoch - 261ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.3361 - acc: 0.8776 - val_loss: 1.3029 - val_acc: 0.7210 - 265ms/epoch - 265ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.3233 - acc: 0.8761 - val_loss: 1.3051 - val_acc: 0.7225 - 262ms/epoch - 262ms/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.3264 - acc: 0.8842 - val_loss: 1.3117 - val_acc: 0.7179 - 263ms/epoch - 263ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.3285 - acc: 0.8812 - val_loss: 1.3182 - val_acc: 0.7179 - 258ms/epoch - 258ms/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.3286 - acc: 0.8832 - val_loss: 1.3267 - val_acc: 0.7164 - 264ms/epoch - 264ms/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.3192 - acc: 0.8847 - val_loss: 1.3380 - val_acc: 0.7195 - 280ms/epoch - 280ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.2983 - acc: 0.8902 - val_loss: 1.3480 - val_acc: 0.7179 - 266ms/epoch - 266ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.3084 - acc: 0.8902 - val_loss: 1.3600 - val_acc: 0.7225 - 269ms/epoch - 269ms/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.3209 - acc: 0.8887 - val_loss: 1.3697 - val_acc: 0.7240 - 260ms/epoch - 260ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.3169 - acc: 0.8867 - val_loss: 1.3785 - val_acc: 0.7240 - 269ms/epoch - 269ms/step

# %%
import stellargraph as sg
sg.utils.plot_history(history)

# %%
test_gen = generator.flow(node_ids_test, enc_target_test)

test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 100ms/step - loss: 0.8191 - acc: 0.7572
#
# Test Set Metrics:
# 	loss: 0.8191
# 	acc: 0.7572

# %% [markdown]
# #### 9.2.3 Visualize the embedded Nodes by extracting the embeddings of the last Convolution Layer and visualizing them using t-SNE.

# %%
all_gen = generator.flow(node_ids)

embedding_model = Model(inputs=x_inp, outputs=x_out)
emb = embedding_model.predict(all_gen)
emb.shape
# Out:
# (1, 3312, 16)

# %%
X = emb.squeeze(0)

trans = TSNE(n_components=2) # TSNE can be replaced by PCA 
X_reduced = trans.fit_transform(X)
X_reduced.shape
# Out:
# C:\tools\Anaconda3\envs\dm1\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\tools\Anaconda3\envs\dm1\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (3312, 2)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 7))

for target_value in np.unique(targets):
    rows_of_target_value = np.where(targets==target_value)
    ax.scatter(
        X_reduced[rows_of_target_value, 0],
        X_reduced[rows_of_target_value, 1],
        alpha=0.4,
        label=target_value
    )

ax.legend(bbox_to_anchor=(1,1));
ax.set(
    aspect="equal",
    xlabel="$X_1$",
    ylabel="$X_2$",
    title=f"TSNE visualization of GCN embeddings for CiteSeer dataset",
);
